# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df= pd.read_csv('kc_house_data.csv',delimiter=",")
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
# There are no missing data in this dataset

df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
# The mean price of the houses in the dataset

df['price'].mean()
# Out:
# 540088.1417665294

# %%
# The mean surface of the houses in the dataset

df['sqft_lot'].mean()
# Out:
# 15106.967565816869

# %%
# The most common number of bedrooms of the houses in the dataset

df['bedrooms'].mode()
# Out:
# 0    3
# dtype: int64

# %%
df['floors'].describe()
# Out:
# count    21613.000000
# mean         1.494309
# std          0.539989
# min          1.000000
# 25%          1.000000
# 50%          1.500000
# 75%          2.000000
# max          3.500000
# Name: floors, dtype: float64

# %%
# The most common number of floors in the houses in the dataset

df['floors'].mode()
# Out:
# 0    1.0
# dtype: float64

# %%
# Distribution of the houses prices

plt.title('Histogram of the prices of the houses')
plt.xlabel('price')
df['price'].plot.hist()
# Out:
# <AxesSubplot:title={'center':'Histogram of the prices of the houses'}, xlabel='price', ylabel='Frequency'>

# %%
# Distribution of the houses surface

plt.title('Histogram of the houses surface')
plt.xlabel('Surface')
df['sqft_lot'].plot.hist()
# Out:
# <AxesSubplot:title={'center':'Histogram of the houses surface'}, xlabel='Surface', ylabel='Frequency'>

# %%
# Distribution of the bedrooms number

plt.title('Histogram of the bedrooms number in the houses')
plt.xlabel('number of bedrooms')
df['bedrooms'].plot.hist()
# Out:
# <AxesSubplot:title={'center':'Histogram of the bedrooms number in the houses'}, xlabel='number of bedrooms', ylabel='Frequency'>

# %%
# Distribution of the number of floors



plt.title('Histogram of the number of floors based on the house surface ')
plt.xlabel('Number of floors')
df['floors'].plot.hist()
# Out:
# <AxesSubplot:title={'center':'Histogram of the number of floors based on the house surface '}, xlabel='Number of floors', ylabel='Frequency'>

# %%
# Distribution of the number of floors based on the house surface

g=sns.FacetGrid(df,col='floors')
g.map(plt.hist,'sqft_lot')

# %%
g = sns.FacetGrid(df, col="floors")
g.map_dataframe(sns.scatterplot, x="floors", y="sqft_lot")
g.set_axis_labels("number of floors", "sqft_lot")
g.add_legend()

# %%
# How to change the scale for sqft_lot

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

def plot_correlation_map (df):
    corr = df.corr()
    s , ax = plt.subplots(figsize =( 12 , 10 ))
    cmap = sns.diverging_palette(220 , 10 , as_cmap = True)
    s = sns.heatmap(corr, cmap = cmap, 
                    square=True, cbar_kws={ 'shrink' : .9 }, ax=ax, annot = True, annot_kws = { 'fontsize' : 8 })

# %%
plot_correlation_map(df)

# %%
# There is a strong correlation between Price and sqt living, grade and sqt above. They can be considered the most important features of this dataset.

# %%
df.head(9)
# Out:
#            id             date      price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000   221900.0         3       1.00         1180
# 1  6414100192  20141209T000000   538000.0         3       2.25         2570
# 2  5631500400  20150225T000000   180000.0         2       1.00          770
# 3  2487200875  20141209T000000   604000.0         4       3.00         1960
# 4  1954400510  20150218T000000   510000.0         3       2.00         1680
# 5  7237550310  20140512T000000  1225000.0         4       4.50         5420
# 6  1321400060  20140627T000000   257500.0         3       2.25         1715
# 7  2008000270  20150115T000000   291850.0         3       1.50         1060
# 8  2414600126  20150415T000000   229500.0         3       1.00         1780
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# ...

# %%
# Split the dataset into training and regression sets 

from sklearn.model_selection import train_test_split
y= df['price']
X= df[['sqft_living']]
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.20, random_state=30)

print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (17290, 1) (4323, 1) (17290,) (4323,)

# %%
# Apply linear regression price vs sqft_living

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn import metrics
model=LinearRegression()   #build linear regression model
model.fit(X_train,y_train)  #fitting the training data
# Out:
# LinearRegression()

# %%
# Plot linear regression price vs sqft_living

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn import metrics

plt.scatter(X,y,color="r")
plt.title("Linear Regression")
plt.ylabel("price")
plt.xlabel("sqft_living")
plt.plot(X,model.predict(X),color="y")
plt.show()

# %%
# Test the performance of the model

predicted=model.predict(X_test) #testing our model’s performance


print("MSE", mean_squared_error(y_test,predicted))
print("R squared", metrics.r2_score(y_test,predicted))
# Out:
# MSE 64179676631.683876
# R squared 0.4879814110728805

# %%
from sklearn.model_selection import train_test_split
y= df['price'].values
X= df[['grade','sqft_living']]
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.35, random_state=40)

print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (14048, 2) (7565, 2) (14048,) (7565,)

# %%
# Apply Multiple regression price vs sqft_living and grade

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn import metrics


model=LinearRegression()   #build linear regression model
model.fit(X_train,y_train)  #fitting the training data
# Out:
# LinearRegression()

# %%
# Test the performance of the multi linear model

predicted=model.predict(X_test) #testing our model’s performance


print("MSE", mean_squared_error(y_test,predicted))
print("R squared", metrics.r2_score(y_test,predicted))
# Out:
# MSE 57413775762.86426
# R squared 0.5433112989852686

# %%
# R squared of multi linear model is bigger than R squared of the linear model. It means multi linear model is more accurate for the prediction.

# %%
# Polynomial model creation

from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures 

# create matrix and vectors
X= df[['grade','sqft_living']]
y= df['price'].values

lg = LinearRegression() 
poly = PolynomialFeatures(degree = 2)

# %%
x_=poly.fit_transform(X)

# %%
x_=poly.fit_transform(X)
print("x before transformation: ", X)
print("x after transformation: ", x_)
lg.fit(x_, y) # Fitting Polynomial Regression to the dataset
# Out:
# x before transformation:         grade  sqft_living
# 0          7         1180
# 1          7         2570
# 2          6          770
# 3          7         1960
# 4          8         1680
# ...      ...          ...
# 21608      8         1530
# 21609      8         2310
# 21610      7         1020
# 21611      8         1600
# 21612      7         1020
#
# [21613 rows x 2 columns]
# x after transformation:  [[1.0000e+00 7.0000e+00 1.1800e+03 4.9000e+01 8.2600e+03 1.3924e+06]
#  [1.0000e+00 7.0000e+00 2.5700e+03 4.9000e+01 1.7990e+04 6.6049e+06]
#  [1.0000e+00 6.0000e+00 7.7000e+02 3.6000e+01 4.6200e+03 5.9290e+05]
#  ...
#  [1.0000e+00 7.0000e+00 1.0200e+03 4.9000e+01 7.1400e+03 1.0404e+06]
#  [1.0000e+00 8.0000e+00 1.6000e+03 6.4000e+01 1.2800e+04 2.5600e+06]
#  [1.0000e+00 7.0000e+00 1.0200e+03 4.9000e+01 7.1400e+03 1.0404e+06]]
# LinearRegression()

# %%
x_test_=poly.fit_transform(x_test)
lg.predict(x_test_)
# Out:
# array([518799.09139831, 565451.1625941 , 565451.1625941 , ...,
#        825833.841078  , 565089.07630451, 645557.5800972 ])

# %%
#Importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_squared_error
from sklearn import metrics

# %%
x= df[['sqft_living', 'grade']]
y= df["price"].values
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=30)  #splitting data
lg=LinearRegression()
poly=PolynomialFeatures(degree=3)
x_train_fit = poly.fit_transform(x_train) #transforming our input data
lg.fit(x_train_fit, y_train)
x_test_ = poly.fit_transform(x_test)
predicted = lg.predict(x_test_)
print("MSE: ", metrics.mean_squared_error(y_test, predicted))
print("R squared: ", metrics.r2_score(y_test,predicted))
# Out:
# MSE:  49245462791.058304
# R squared:  0.607124970198232

# %%
# Polynomial model has a greater R squared, it means it is more accurate than linear and multilinear regressions

# %%
x= df["sqft_living"].values.reshape(-1,1)
y= df["price"].values
poly = PolynomialFeatures(degree = 3)
x_poly = poly.fit_transform(x)
poly.fit(x_poly, y)
lg=LinearRegression()
lg.fit(x_poly, y)
plt.scatter(x, y, color="r")
plt.title("Linear regression")
plt.ylabel("price")
plt.xlabel("sqft_living")
plt.plot(x, lg.predict(poly.fit_transform(x)), color="g")
